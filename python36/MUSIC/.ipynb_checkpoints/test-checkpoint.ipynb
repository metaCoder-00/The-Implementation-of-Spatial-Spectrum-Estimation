# %%
import Ipynb_importer
import matplotlib.pyplot as plt
import MUSIC
import numpy as np
from scipy import signal

# %%
theta, P = MUSIC.SS_MUSIC()
plt.semilogy(theta, abs(P)/abs(P).max())
plt.show()
